# %%
# !unzip /content/test.zip
# Out:
# Archive:  /content/test.zip
#   inflating: test/closed eye g.jpg
#   inflating: test/closed eye g2.jpg
#   inflating: test/closed eye.jpg
#   inflating: test/download.jpg
#   inflating: test/o.jpg
#   inflating: test/op glasses m.jpg
#   inflating: test/op glasses w.jpg

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from PIL import Image

# Load the model
model = load_model('model.h5')

# Set the target input dimensions of the model
target_height, target_width = 128, 128  # Update with your model's input dimensions

# Path to your single test image
image_path = '/content/test/closed eye.jpg'  # Replace with your image path

# Load and preprocess the single image
img = image.load_img(image_path, target_size=(target_height, target_width))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
processed_img = img_array / 255.0  # Normalize pixel values

# Make predictions
predictions = model.predict(processed_img)
predicted_label = np.argmax(predictions, axis=-1)[0]

if predicted_label == 0:
    print("The person is opening his eyes")
else:
    print("The person is closeing his eyes")


plt.imshow(Image.open(image_path))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 198ms/step
# The person is closeing his eyes
